# %% [markdown]
# # Loading the Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("D:\\Codegnan\\Data Science\\Class\\Assignments\\Assignment-3(EDA)\\archive\\netflix_titles_2021.csv")

# %%
display(df)
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# ## 1. Understanding the Dataset

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
df.sample(10)
# Out:
#      show_id     type                                          title  \
# 6538   s6539  TV Show                                  Court Justice
# 6657   s6658    Movie                                  Earth to Echo
# 4103   s4104    Movie                                          Fatso
# 2090   s2091    Movie                              Edge of Seventeen
# 1718   s1719  TV Show                                        Trial 4
# 5574   s5575    Movie                                     One 2 Ka 4
# 5820   s5821    Movie  Lavell Crawford: Can a Brother Get Some Love?
# 2501   s2502    Movie                         Either Me Or My Auntie
# 7928   s7929    Movie                                         Samson
# 6202   s6203    Movie                                          Azhar
#
#                               director  \
# 6538                               NaN
# 6657                        Dave Green
# 4103                      Rajat Kapoor
# 2090                     David Moreton
# ...

# %%
df.select_dtypes(include = 'int64').columns
# Out:
# Index(['release_year'], dtype='object')

# %%
df.select_dtypes(include = 'object').columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.describe(include = 'object')
# Out:
#        show_id   type                 title       director  \
# count     8807   8807                  8807           6173
# unique    8807      2                  8807           4528
# top         s1  Movie  Dick Johnson Is Dead  Rajiv Chilaka
# freq         1   6131                     1             19
#
#                       cast        country       date_added rating  duration  \
# count                 7982           7976             8797   8803      8804
# unique                7692            748             1767     17       220
# top     David Attenborough  United States  January 1, 2020  TV-MA  1 Season
# freq                    19           2818              109   3207      1793
#
#                            listed_in  \
# count                           8807
# unique                           514
# top     Dramas, International Movies
# freq                             362
#
#                                               description
# ...

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.loc[0:5,'type':'country']
# Out:
#       type                  title         director  \
# 0    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1  TV Show          Blood & Water              NaN
# 2  TV Show              Ganglands  Julien Leclercq
# 3  TV Show  Jailbirds New Orleans              NaN
# 4  TV Show           Kota Factory              NaN
# 5  TV Show          Midnight Mass    Mike Flanagan
#
#                                                 cast        country
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...            NaN

# %%
df.iloc[0:5, 3:5]
# Out:
#           director                                               cast
# 0  Kirsten Johnson                                                NaN
# 1              NaN  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2  Julien Leclercq  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3              NaN                                                NaN
# 4              NaN  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...

# %% [markdown]
# ## Filtering

# %%
movies = df[df['type'] == 'Movie']
display(movies.head(5))
# Out:
#    show_id   type                             title  \
# 0       s1  Movie              Dick Johnson Is Dead
# 6       s7  Movie  My Little Pony: A New Generation
# 7       s8  Movie                           Sankofa
# 9      s10  Movie                      The Starling
# 12     s13  Movie                      Je Suis Karl
#
#                          director  \
# 0                 Kirsten Johnson
# 6   Robert Cullen, José Luis Ucha
# 7                    Haile Gerima
# 9                  Theodore Melfi
# 12            Christian Schwochow
#
#                                                  cast  \
# 0                                                 NaN
# 6   Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 7   Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 9   Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12  Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
#
#                                               country          date_added  \
# ...

# %%
df.sort_values('release_year', ascending = True)
# Out:
#      show_id     type                                          title  \
# 4250   s4251  TV Show              Pioneers: First Women Filmmakers*
# 7790   s7791    Movie                                 Prelude to War
# 8205   s8206    Movie                           The Battle of Midway
# 8660   s8661    Movie  Undercover: How to Operate Behind Enemy Lines
# 8739   s8740    Movie             Why We Fight: The Battle of Russia
# ...      ...      ...                                            ...
# 862     s863  TV Show                                        Special
# 861     s862    Movie             Little Singham Future mein Satakli
# 857     s858  TV Show                                   The Neighbor
# 876     s877  TV Show                                   Alma Matters
# 965     s966  TV Show                                         Yasuke
#
#                          director  \
# 4250                          NaN
# 7790                  Frank Capra
# ...

# %%
df.nlargest(9,'release_year')
# Out:
#    show_id     type                                title  \
# 1       s2  TV Show                        Blood & Water
# 2       s3  TV Show                            Ganglands
# 3       s4  TV Show                Jailbirds New Orleans
# 4       s5  TV Show                         Kota Factory
# 5       s6  TV Show                        Midnight Mass
# 6       s7    Movie     My Little Pony: A New Generation
# 8       s9  TV Show        The Great British Baking Show
# 9      s10    Movie                         The Starling
# 10     s11  TV Show  Vendetta: Truth, Lies and The Mafia
#
#                          director  \
# 1                             NaN
# 2                 Julien Leclercq
# 3                             NaN
# 4                             NaN
# 5                   Mike Flanagan
# 6   Robert Cullen, José Luis Ucha
# 8                 Andy Devonshire
# 9                  Theodore Melfi
# 10                            NaN
#
# ...

# %%
df.nsmallest(9,'release_year')
# Out:
#      show_id     type                                             title  \
# 4250   s4251  TV Show                 Pioneers: First Women Filmmakers*
# 7790   s7791    Movie                                    Prelude to War
# 8205   s8206    Movie                              The Battle of Midway
# 8660   s8661    Movie     Undercover: How to Operate Behind Enemy Lines
# 8739   s8740    Movie                Why We Fight: The Battle of Russia
# 8763   s8764    Movie                   WWII: Report from the Aleutians
# 8419   s8420    Movie  The Memphis Belle: A Story of a\nFlying Fortress
# 8436   s8437    Movie                                 The Negro Soldier
# 8640   s8641    Movie                                  Tunisian Victory
#
#                                                director  \
# 4250                                                NaN
# 7790                                        Frank Capra
# 8205                                          John Ford
# ...

# %%
df.nunique()
# Out:
# show_id         8807
# type               2
# title           8807
# director        4528
# cast            7692
# country          748
# date_added      1767
# release_year      74
# rating            17
# duration         220
# listed_in        514
# description     8775
# dtype: int64

# %% [markdown]
# ## 2. What different types of show or movie are uploaded on Netflix?

# %%
df['type'].unique()
# Out:
# array(['Movie', 'TV Show'], dtype=object)

# %%
df['type'].value_counts()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: count, dtype: int64

# %%
sns.countplot(data=df, x="type", hue="type", palette=["royalblue", "darkorange"], legend=False)
plt.title("Distribution of Movies and TV Shows on Netflix")
plt.show()

# %% [markdown]
# # 3. What is the Correlation between the features?

# %%
numerical_columns = df.select_dtypes(include = ['int64','float64'])

correlation_matrix = numerical_columns = numerical_columns.corr()

print(correlation_matrix)
# Out:
#               release_year
# release_year           1.0

# %% [markdown]
# ## 4. Most watched shows on the Netflix?

# %%
df['title'].value_counts().head(1)
# Out:
# title
# Dick Johnson Is Dead    1
# Name: count, dtype: int64

# %% [markdown]
# ## 5. Distribution of Ratings

# %%
sns.countplot(data = df, y = "rating",order = df['rating'].value_counts().index)
plt.title("Distribution of Ratings on Netflix")
plt.show()

# %% [markdown]
# ## 6. Which has the highest rating: TV shows or Movies?

# %%
import pandas as pd

# Calculate the counts of each rating for Movies and TV Shows
rating_counts = df.groupby("type")["rating"].value_counts().unstack()

# Display the sum of ratings for each type
rating_counts.sum(axis=1)
# Out:
# type
# Movie      6129.0
# TV Show    2674.0
# dtype: float64

# %%
df.groupby("type")['rating'].value_counts().unstack().plot(kind = 'bar',figsize = (10,5),colormap ='viridis')
plt.title("Comparision of ratings for Movies vs TV shows")
plt.ylabel("Count")
plt.show()

# %%
type_counts = df["type"].value_counts()

plt.figure(figsize=(6, 6))
plt.pie(type_counts, labels=type_counts.keys(), autopct="%1.1f%%", colors=["#ffefa0", "#90e0ef"], startangle=90)
plt.title("Distribution of Movies vs. TV Shows")
plt.show()

# %% [markdown]
# ## 7. Finding the Best Month for Releasing Content

# %%
df.date_added.unique()
# Out:
# array(['September 25, 2021', 'September 24, 2021', 'September 23, 2021',
#        ..., 'December 6, 2018', 'March 9, 2016', 'January 11, 2020'],
#       dtype=object)

# %%
df["month_added"] = df["date_added"].str.split().str[0]  # Extract month name
print(df["month_added"].value_counts())
## July is the best month for releasing content
# Out:
# month_added
# July         827
# December     813
# September    770
# April        764
# October      760
# August       755
# March        742
# January      738
# June         728
# November     705
# May          632
# February     563
# Name: count, dtype: int64

# %% [markdown]
# ## 8. Highest watched genres on Netflix?

# %%
df['listed_in'].value_counts().head(1)  # Shows top category & count
# Out:
# listed_in
# Dramas, International Movies    362
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
#  12  month_added   8797 non-null   object
# dtypes: int64(1), object(12)
# memory usage: 894.6+ KB

# %% [markdown]
# ## 9. Released movies over the years?

# %%
sns.histplot(df[df["type"] == "Movie"]["release_year"], bins=30, kde=True, color = 'teal')
plt.title("Movies Released Over the Years")
plt.xlabel("Release Year")
plt.ylabel("Number of Movies")
plt.grid()
plt.show()

# %% [markdown]
# ## 10. Movies made on a yearly basis?

# %%
print(df[df["type"] == "Movie"]["release_year"].value_counts().sort_index())
# Out:
# release_year
# 1942      2
# 1943      3
# 1944      3
# 1945      3
# 1946      1
#        ...
# 2017    767
# 2018    767
# 2019    633
# 2020    517
# 2021    277
# Name: count, Length: 73, dtype: int64

# %%
plt.figure(figsize=(12, 5))
movies_per_year = df[df['type'] == 'Movie']['release_year'].value_counts().sort_index()

sns.barplot(x=movies_per_year.index, y=movies_per_year.values, hue=movies_per_year.index, palette="coolwarm", legend=False)
plt.xticks(rotation=90)
plt.xlabel("Year")
plt.ylabel("Number of Movies")
plt.title("Movies Made on a Yearly Basis")
plt.show()

# %% [markdown]
# ## 11. What is the show ID and director for "House of Cards"?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
#  12  month_added   8797 non-null   object
# dtypes: int64(1), object(12)
# memory usage: 894.6+ KB

# %%
df[df['title'] == "House of Cards"][["show_id","director"]]
# Out:
#      show_id director
# 1059   s1060      NaN

# %% [markdown]
# ## 12. Show all the movies that were released in the year 2000.

# %%
display(df[(df['release_year'] == 2000) & (df['type'] == 'Movie')])
# Out:
#      show_id   type                                              title  \
# 180     s181  Movie                 The Nutty Professor II: The Klumps
# 350     s351  Movie                                      Space Cowboys
# 359     s360  Movie                       The Original Kings of Comedy
# 566     s567  Movie                                   Charlie's Angels
# 593     s594  Movie                                           Snow Day
# 779     s780  Movie                                  Battlefield Earth
# 952     s953  Movie                               The Whole Nine Yards
# 3472   s3473  Movie                        Rugrats in Paris: The Movie
# 4545   s4546  Movie             Monty Python: Before the Flying Circus
# 4723   s4724  Movie                                               Fiza
# 4956   s4957  Movie                        Phir Bhi Dil Hai Hindustani
# 5953   s5954  Movie                             Joseph: King of Dreams
# ...

# %% [markdown]
# ## 13. Show only the title of all TV shows released in India.

# %%
tvshows_india = df[(df['type'] == 'TV Show') & (df['country'] == 'India')]['title']
display(tvshows_india.head())
# Out:
# 4                       Kota Factory
# 39                      Chhota Bheem
# 50                     Dharmakshetra
# 66     Raja Rasoi Aur Anya Kahaniyan
# 69    Stories by Rabindranath Tagore
# Name: title, dtype: object

# %% [markdown]
# ## 14. Top 10 directors who gave the highest number of TV shows & movies to Netflix?

# %%
df.director.value_counts().head(10)
# Out:
# director
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Name: count, dtype: int64

# %% [markdown]
# ## 15. In how many movies/TV shows was "Tom Cruise" cast?

# %%
df[df['cast'].str.contains("Tom Cruise", na=False)]['type'].value_counts()
# Out:
# type
# Movie    2
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (8807, 13)

# %% [markdown]
# ## 16. How many movies got the "TV-14" rating in Canada?

# %%
display(df[(df["rating"] == "TV-14") & (df["country"] == "Canada") & (df["type"] == "Movie")].shape[0])
# Out:
# 13
